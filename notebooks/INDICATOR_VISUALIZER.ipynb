# %%
import sys
sys.path.append('C:/openclassroom/projet-2/src')
import EdTechVisualtionIndicator as ev


datagrid_widget = ev.create_datagrid_and_visualizer_by_indicator('../data/statistiqueParRegions/statsByregions.csv')
display(datagrid_widget)
# Call the functions 'NY.GDP.MKTP.CD'
